# %%
import random

def generate_smart_birthday_message(name):
    messages = [
        f"On your birthday, {name}, may your code compile on the first try and your bugs be easy to fix!",
        f"Happy birthday, {name}! May your algorithms always run efficiently and your variables never be null.",
        f"Wishing you a birthday filled with the elegance of well-written code and the satisfaction of bug-free software, {name}!",
        f"{name}, on your special day, may your logic always be flawless and your syntax error-free. Happy birthday!",
        f"Happy birthday, {name}! May your functions always return the expected output and your loops never be infinite.",
        f"Here's to a birthday as brilliant as your algorithms, {name}! May your programs be efficient and your data structures impeccable.",
        f"Wishing you a birthday filled with the precision of binary and the flexibility of Python, {name}! Keep coding like a champ!",
        f"{name}, may your birthday be as efficient as bubble sort and as powerful as a recursive function. Happy coding!"
    ]
    return random.choice(messages)

# Replace 'name' with the name of the person celebrating their birthday
name = "Magda"
print(generate_smart_birthday_message(name))
# Out:
# Happy birthday, Magda! May your functions always return the expected output and your loops never be infinite.
